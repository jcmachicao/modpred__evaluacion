# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmachicao/modpred__evaluacion/blob/main/modpred__missingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import missingno as mno

# %%
data = pd.read_excel('drive/My Drive/2020 data/ActosViolentos_missing.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Edad      888 non-null    object
#  1   Hora      892 non-null    float64
#  2   Sexo      900 non-null    object
#  3   Area      891 non-null    object
#  4   Ingreso   899 non-null    float64
#  5   Violento  900 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 42.3+ KB

# %%
mno.matrix(data)

# %%
mno.bar(data)

# %%
mno.heatmap(data)

# %% [markdown]
# https://analyticsindiamag.com/tutorial-on-missingno-python-tool-to-visualize-missing-values/
